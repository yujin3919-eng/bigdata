# %%
# pip install
# !pip install SomePackage   # 또는 터미널에 ! 빼고 작성
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Created wheel for SomePackage: filename=somepackage-1.2.3-py3-none-any.whl size=9359 sha256=7ccc2fc310494e4bd5e8975a6e4ec18b8b46354c9b56b31d1a6c3f827aa3db15
#   Stored in directory: c:\users\nt371b5a\appdata\local\pip\cache\wheels\a7\83\76\505cb3c27a317975c4433e10969145d3dfd7ca69705c80a03b
# Successfully built SomePackage
# ...

# %%
# pip install [패키지명] -> 설치
# pip uninstall [패키지명] -> 삭제
# pip install [패키지명]==[버전] -> 특정 버전을 설치
# pip list -> 설치된 패키지 리스트 확인

# %%
# !pip install Faker
# Out:
# ...
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    --------------------- ------------------ 1.0/2.0 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 11.0 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [tzdata]
#    ---------------------------------------- 0/2 [tzdata]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
#    -------------------- ------------------- 1/2 [Faker]
# ...

# %%
# from faker import Faker
import faker    # 으로 해도 무관

# fake = Faker()
# fake.name()
# fake.address()


# for _ in range(10):
#     print(fake.name())

a = faker.Faker()
a.name()
# Out:
# 'Stephanie Cox'
